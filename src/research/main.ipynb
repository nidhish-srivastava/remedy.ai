# %%
from langchain_community.embeddings import HuggingFaceInferenceAPIEmbeddings
import os
from dotenv import load_dotenv
load_dotenv()
hf_inference_api_key=os.getenv("HF_INFERENCE_API_KEY")
# Out:
# True

# %%
from pinecone import Pinecone

pc = Pinecone(api_key="3c3d6d79-c118-41e4-8ba1-8a31a096136e")
index = pc.Index("testing-remedy")

index.delete(delete_all=True, namespace='')
# Out:
# {}

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/BAAI/bge-large-en-v1.5"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": "Today is a sunny day and I will get some ice cream.",
})
output

# %%
rs=embeddings.embed_documents(["Hello, world! This is a test sentence."])
rs
# Out:
# [[0.026335924863815308,
#   0.016620643436908722,
#   0.015605178661644459,
#   0.031768251210451126,
#   -0.0534304715692997,
#   -0.011222196742892265,
#   0.03519804775714874,
#   0.017729271203279495,
#   0.02971736714243889,
#   0.002814284060150385,
#   0.007106425240635872,
#   0.011312401853501797,
#   -0.0059844921343028545,
#   -0.0021553703118115664,
#   -0.042941395193338394,
#   -0.020181352272629738,
#   -0.03200298547744751,
#   -0.001361729227937758,
#   -0.03277453035116196,
#   0.0026038652285933495,
#   -0.01536448672413826,
#   0.01670822873711586,
#   -0.07488210499286652,
#   0.012439601123332977,
#   -0.020246833562850952,
#   0.036075249314308167,
#   0.019051602110266685,
#   -0.001038886490277946,
#   0.0589887835085392,
#   0.04278517886996269,
#   0.004229930695146322,
#   0.03227359429001808,
#   -0.029514659196138382,
#   -0.06329803913831711,
#   0.010079164057970047,
#   -0.03743017092347145,
#   0.07107304781675339,
#   -0.04131095111370087,
# ...

# %%
def embed_text(texts):
    embeddings = HuggingFaceInferenceAPIEmbeddings(
    api_key=hf_inference_api_key, model_name="BAAI/bge-large-en-v1.5",api_url=API_URL
)
    if isinstance(texts, str):
        texts = [texts]
    embedding = embeddings.embed_documents(texts)
    return embedding

# Test the embedding function with sample text
sample_text = "This is a test sentence to check embeddings."
embedded_text = embed_text(sample_text)

print("Embedded Text:", embedded_text)
# Out:
# Embedded Text: [[0.007379407528787851, 0.006749519146978855, 0.0001775849232217297, 0.010949692688882351, -0.028912346810102463, -0.021922606974840164, -0.0004184398567304015, -0.014895755797624588, 0.02972044050693512, 0.010047595016658306, 0.02695263735949993, 0.0014684130437672138, 0.013956370763480663, -0.021912680938839912, -0.02131504751741886, -0.029729299247264862, -0.004304724279791117, -0.008705084212124348, -0.011645509861409664, -0.030426761135458946, -0.01914886012673378, 0.03360946848988533, -0.0837261825799942, 0.005848586093634367, -0.03802035003900528, 0.03414388373494148, 0.03990394249558449, 0.016056867316365242, 0.06841360777616501, 0.015146978199481964, 0.006032109260559082, 0.035897303372621536, 0.007332276552915573, -0.043434057384729385, 0.0005368116544559598, -0.012412624433636665, 0.059254951775074005, -0.03449064493179321, -0.001069104066118598, -0.039198022335767746, 0.0069769383408129215, -0.015420432202517986, 0.04284828156232834, -0.03548349440097809, -
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from sentence_transformers import SentenceTransformer
from langchain.document_loaders import DirectoryLoader
from langchain.document_loaders import PyPDFLoader

# %%
from langchain.document_loaders import PyMuPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Specify the directory containing PDF documents
directory_path = r'A:\Downloads\LLM-RAG-Using-Flask\RAG\Docs\baptist_abhi.pdf'

# Initialize the PyMuPDFLoader with the directory path
loader = PyMuPDFLoader(directory_path)

# Load documents from the specified directory
documents = loader.load()

# Split the documents into shorter chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=10)
texts = text_splitter.split_documents(documents)

# Print the first document chunk to check the output
documents
# Out:
# [Document(page_content='CERTIFICATE FROM THE TREATING PHYSICIAN\nDate: 24/04/2024\nThis is to inform you that Mr. Abhishek Kumar Singh, UHID No: AA27142 residing at Kavery\nBoys Hotel, Nitte Meenakshi Institute of Technology, Yelahanka 560064 was examined and\ntreated at Bangalore Baptist Hospital from\n15/04/24 to 20/04/24 with the following\ndiagnosis Acute Left Foot Ligament Injury [Grade III] and required medical attention on the\nabove mentioned dates. He would require bed rest for a few more days.\nDr. Abhijit Jawali A.\nMBBS, D’Ortho, DNB – Orthopaedics, FIJR\nConsultant -\nOrthopaedics & Joint Replacement\nAddress:\nPhone Number: +91 – 80 – 22024700\nBangalore Baptist Hospital,\nEmail: talk2us@bbh.org.in\nBellary Road, Hebbal,\nBangalore – 560024\n', metadata={'source': 'A:\\Downloads\\LLM-RAG-Using-Flask\\RAG\\Docs\\baptist_abhi.pdf', 'file_path': 'A:\\Downloads\\LLM-RAG-Using-Flask\\RAG\\Docs\\baptist_abhi.pdf', 'page': 0, 'total_pages': 1, 'format': 'PDF 1.7', 'title': '',
# ...

# %%
texts
# Out:
# [Document(page_content='CERTIFICATE FROM THE TREATING PHYSICIAN\nDate: 24/04/2024', metadata={'source': 'A:\\Downloads\\LLM-RAG-Using-Flask\\RAG\\Docs\\baptist_abhi.pdf', 'file_path': 'A:\\Downloads\\LLM-RAG-Using-Flask\\RAG\\Docs\\baptist_abhi.pdf', 'page': 0, 'total_pages': 1, 'format': 'PDF 1.7', 'title': '', 'author': 'mbavi', 'subject': '', 'keywords': '', 'creator': 'WPS Writer', 'producer': '', 'creationDate': "D:20240510230751+17'37'", 'modDate': "D:20240510230751+17'37'", 'trapped': ''}),
# ...

# %%
API_URL = "https://api-inference.huggingface.co/models/BAAI/bge-large-en-v1.5"
from langchain_community.embeddings import HuggingFaceInferenceAPIEmbeddings

embeddings = HuggingFaceInferenceAPIEmbeddings(
    api_key=hf_inference_api_key, model_name="BAAI/bge-large-en-v1.5",api_url=API_URL
)

# %%
def embed_text(texts):
    embeddings = HuggingFaceInferenceAPIEmbeddings(
    api_key=hf_inference_api_key, model_name="BAAI/bge-large-en-v1.5",api_url=API_URL
)
    if isinstance(texts, str):
        texts = [texts]
    embedding = embeddings.embed_documents(texts)
    return embedding

# %%
textss = [doc.page_content for doc in texts]
metadata_list = [doc.metadata for doc in texts]

# %%
dense_values = []
for chunk in textss:
    val=embed_text([chunk])
    dense_values.append(val)
dense_values
# Out:
# [[[0.005034349858760834,
#    -0.022908993065357208,
#    -0.01477906946092844,
#    0.05456371232867241,
#    -0.051085762679576874,
#    -0.040862299501895905,
#    0.016451388597488403,
#    0.007664119359105825,
#    0.010858079418540001,
#    0.026689160615205765,
#    0.02043045684695244,
#    0.0018797048833221197,
#    0.026307931169867516,
#    0.012852621264755726,
#    -0.026293622329831123,
#    0.018237978219985962,
#    -0.0004355202545411885,
#    -0.007138334680348635,
#    -0.021919814869761467,
#    0.02672255039215088,
#    -0.01965421251952648,
#    0.04605259373784065,
#    -0.045305751264095306,
#    -0.0062776836566627026,
#    -0.021970830857753754,
#    0.019531775265932083,
#    -0.03050769492983818,
#    0.005108412820845842,
#    0.051016271114349365,
#    0.049435749650001526,
#    -0.07342368364334106,
#    0.02168571762740612,
#    0.028940564021468163,
#    -0.025288360193371773,
#    0.00297393836081028,
#    -0.034166011959314346,
# ...

# %%
data = []
for idx, (metadata, dense) in enumerate(zip(metadata_list, dense_values)):
    flattened_dense = [item for sublist in dense for item in sublist]  # Flatten the dense list
    data.append(
        {
            'id': f'vec{idx}',
            'values': flattened_dense,
            'metadata': metadata,
        }
    )

# %%
data
# Out:
# [{'id': 'vec0',
#   'values': [0.005034349858760834,
#    -0.022908993065357208,
#    -0.01477906946092844,
#    0.05456371232867241,
#    -0.051085762679576874,
#    -0.040862299501895905,
#    0.016451388597488403,
#    0.007664119359105825,
#    0.010858079418540001,
#    0.026689160615205765,
#    0.02043045684695244,
#    0.0018797048833221197,
#    0.026307931169867516,
#    0.012852621264755726,
#    -0.026293622329831123,
#    0.018237978219985962,
#    -0.0004355202545411885,
#    -0.007138334680348635,
#    -0.021919814869761467,
#    0.02672255039215088,
#    -0.01965421251952648,
#    0.04605259373784065,
#    -0.045305751264095306,
#    -0.0062776836566627026,
#    -0.021970830857753754,
#    0.019531775265932083,
#    -0.03050769492983818,
#    0.005108412820845842,
#    0.051016271114349365,
#    0.049435749650001526,
#    -0.07342368364334106,
#    0.02168571762740612,
#    0.028940564021468163,
#    -0.025288360193371773,
#    0.00297393836081028,
# ...

# %%
from pinecone import Pinecone

pc = Pinecone(api_key="3c3d6d79-c118-41e4-8ba1-8a31a096136e")
index = pc.Index("testing-remedy")

# %%
for i in range(0, len(data), 128):
            index.upsert( vectors=data[i:i + 128])

# %%
import google.generativeai as genai
import pathlib
import textwrap
from IPython.display import Markdown
import PIL.Image
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
genai.configure(api_key=GEMINI_API_KEY)
model = genai.GenerativeModel('models/gemini-pro-vision')

# %%
print("Loading Image")
img_path = pathlib.Path(r"C:\Users\akash\Downloads\report_medical_1.jpg")
img = PIL.Image.open(img_path)
prompt_template = '''
You are an experienced and highly skilled doctor with extensive knowledge in interpreting medical texts and analyzing medical scans such as X-Rays, CT-Scans, and MRIs. 

1. If the given image contains handwritten text, carefully read and transcribe all the text, ensuring accuracy despite the challenging handwriting.
2. If the image includes medical scans or reports with limited text, analyze the scan thoroughly. Provide a detailed and accurate interpretation of the findings based on your extensive medical knowledge and expertise. 
3. Summarize the analysis in a clear and concise manner, suitable for medical professionals.

Please proceed with the analysis.
'''
# Generate content from the image
response = model.generate_content([prompt_template, img], stream=True)
response.resolve()
text = response.text

# Wrap the text to fit the display
# Out:
# Loading Image

# %%
Markdown(text)
# Out:
#  **Patient Name:** Aditya Sinha
# **Age:** 20 years 5 months 12 days
# **Sex:** Male
#
# **Address:** J 704 Sarjan Tower, Memnagar, Ahmedabad-380052
#
# **Phone No.:** 9909036865
# **IPD No.:** 1144901
# **Ward No.:** 9th Floor
# **Pt. No.:** 328172
# **Admn. Dttm.:** 30/04/2023 22:29
# **Dtsch.:** 18/05/2023
# **Treating Doc.:** Dr. Milan Bansi bhai Lekhadia (M.D.Medicine)
#
# **Diagnosis with ICD codes**
# Dengue + enteric fever (A090)
#
# **Present Illness and Hospital Course**
# A 20 yrs old male patient complained of high-grade fever, bodyache, generalized weakness with decreased appetite since 6 days. Out sided covid-19 PCR was negative. Patient was admitted in SAL hospital under care of Dr. Milan Lekhadia for further management.
#
# ...
